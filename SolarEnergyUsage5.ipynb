# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Renewable_Energy_Usage_Sampled.csv")
df.head()
# Out:
#   Household_ID         Region    Country Energy_Source  Monthly_Usage_kWh  \
# 0       H01502  North America        USA         Hydro            1043.49
# 1       H02587      Australia  Australia    Geothermal             610.01
# 2       H02654  North America        USA       Biomass            1196.75
# 3       H01056  South America   Colombia       Biomass             629.67
# 4       H00706         Africa      Egypt         Hydro             274.46
#
#    Year  Household_Size Income_Level Urban_Rural  Adoption_Year  \
# 0  2024               5          Low       Urban           2012
# 1  2024               4         High       Rural           2023
# 2  2024               8          Low       Rural           2017
# 3  2024               7         High       Urban           2023
# 4  2022               7       Middle       Rural           2010
#
#   Subsidy_Received  Cost_Savings_USD
# 0               No             10.46
# 1               No             43.49
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Household_ID       1000 non-null   object
#  1   Region             1000 non-null   object
#  2   Country            1000 non-null   object
#  3   Energy_Source      1000 non-null   object
#  4   Monthly_Usage_kWh  1000 non-null   float64
#  5   Year               1000 non-null   int64
#  6   Household_Size     1000 non-null   int64
#  7   Income_Level       1000 non-null   object
#  8   Urban_Rural        1000 non-null   object
#  9   Adoption_Year      1000 non-null   int64
#  10  Subsidy_Received   1000 non-null   object
#  11  Cost_Savings_USD   1000 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#        Monthly_Usage_kWh         Year  Household_Size  Adoption_Year  \
# count        1000.000000  1000.000000     1000.000000    1000.000000
# mean          767.325530  2021.992000        4.480000    2015.992000
# std           419.649102     1.419137        2.297581       3.973629
# min            50.740000  2020.000000        1.000000    2010.000000
# 25%           402.730000  2021.000000        2.000000    2013.000000
# 50%           760.190000  2022.000000        5.000000    2016.000000
# 75%          1117.747500  2023.000000        6.000000    2019.000000
# max          1497.340000  2024.000000        8.000000    2024.000000
#
#        Cost_Savings_USD
# count       1000.000000
# mean         248.389850
# std          143.127301
# min           10.420000
# 25%          122.122500
# 50%          242.530000
# 75%          372.520000
# max          499.830000

# %%
df.isnull().sum()
# Out:
# Household_ID         0
# Region               0
# Country              0
# Energy_Source        0
# Monthly_Usage_kWh    0
# Year                 0
# Household_Size       0
# Income_Level         0
# Urban_Rural          0
# Adoption_Year        0
# Subsidy_Received     0
# Cost_Savings_USD     0
# dtype: int64

# %%
df.drop(columns=["Household_ID","Country","Income_Level","Cost_Savings_USD"],inplace=True)
df.head()
# Out:
#           Region Energy_Source  Monthly_Usage_kWh  Year  Household_Size  \
# 0  North America         Hydro            1043.49  2024               5
# 1      Australia    Geothermal             610.01  2024               4
# 2  North America       Biomass            1196.75  2024               8
# 3  South America       Biomass             629.67  2024               7
# 4         Africa         Hydro             274.46  2022               7
#
#   Urban_Rural  Adoption_Year Subsidy_Received
# 0       Urban           2012               No
# 1       Rural           2023               No
# 2       Rural           2017              Yes
# 3       Urban           2023               No
# 4       Rural           2010               No

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Region'] = label_encoder.fit_transform(df['Region'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Energy_Source'] = label_encoder.fit_transform(df['Energy_Source'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Urban_Rural'] = label_encoder.fit_transform(df['Urban_Rural'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Subsidy_Received'] = label_encoder.fit_transform(df['Subsidy_Received'])

# %%
df.head()
# Out:
#    Region  Energy_Source  Monthly_Usage_kWh  Year  Household_Size  \
# 0       4              2            1043.49  2024               5
# 1       2              1             610.01  2024               4
# 2       4              0            1196.75  2024               8
# 3       5              0             629.67  2024               7
# 4       0              2             274.46  2022               7
#
#    Urban_Rural  Adoption_Year  Subsidy_Received
# 0            1           2012                 0
# 1            0           2023                 0
# 2            0           2017                 1
# 3            1           2023                 0
# 4            0           2010                 0

# %%
# Step 3: Split features and target variable
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Monthly_Usage_kWh"])
y = df["Monthly_Usage_kWh"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# Print results
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 377.06706402873164
# Mean Squared Error: 185696.62692292035
# R-squared Score: -0.010895260673980056
